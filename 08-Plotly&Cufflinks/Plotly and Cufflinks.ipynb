# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # You must install plotly & cufflinks in your terminal(anaconda promt) before you import the library

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 5.5.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
#For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#For Offline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Data Fake
# random.randn untuk membuat fake data frame (100 = columns & 4 = Rows)
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df
# Out:
#            A         B         C         D
# 0  -0.546214 -0.458457 -0.780457 -0.533308
# 1   0.084098 -2.613667  0.083948 -0.801787
# 2   0.819471 -0.875514  0.613109 -0.049760
# 3   0.198450  2.287746 -1.367147  0.209426
# 4  -0.065370  0.125902  0.218210  0.642316
# ..       ...       ...       ...       ...
# 95 -0.423364  0.957212 -1.929123 -0.224070
# 96 -1.025422 -0.054955 -1.657780 -0.096700
# 97  0.100858  2.688529 -0.289657  0.178000
# 98 -0.586730  0.308475  0.313202  1.786247
# 99 -1.024515 -0.706189  0.663545  0.328497
#
# [100 rows x 4 columns]

# %%
# INSERT FAKE DATA FRAME
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32, 42, 50]})
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      42
# 2        C      50

# %%
df.iplot()
# Out:
# <div>                            <div id="67adfb76-a717-46fa-8e20-1e5344280292" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Scatter Plot

# %%
df.iplot(kind='scatter',x='A', y='B',mode='markers',size=15)
# Out:
# <div>                            <div id="13c477d1-f460-479d-b5fc-2f122b17bd5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Bar Plot

# %%
df2.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div>                            <div id="964502d7-9441-47a0-82e6-526e24858e8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar')
# Out:
# <div>                            <div id="f4e09d58-c6df-439c-83f5-14902a4f4228" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="a5daf3f2-336c-4df0-bf0b-ca2826ed4d65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Box Plot

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="cb6e5c91-71a3-4998-847f-17703f0b0635" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'X':[1,2,3,4,5], 'Y':[10,20,30,20,10], 'Z':[5,4,3,2,1]})
df3
# Out:
#    X   Y  Z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %% [markdown]
# # Surface Plot

# %%
df3.iplot(kind='surface',colorscale='rdylbu')

# df3.iplot(kind='surface')
# Out:
# <div>                            <div id="44fd2ef8-a3b9-4ce6-8e07-e2db74a3d10a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind='hist', bins=50)
# Out:
# <div>                            <div id="4aaa6220-1a5d-40bc-92a9-2b1ac6122be9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>                            <div id="258e3a3a-84f1-4aad-9a1e-b1255c305b92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# <div>                            <div id="fdefd651-8d1d-4e65-8e96-fe700cfc77f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="bac4e179-0ae9-4f82-9502-2d176e6ee07a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="d776c8cb-ef1e-4fd8-8609-b6e95e36632a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df=cf.datagen.ohlc()
qf=cf.QuantFig(df,title='First Quant Figure',legend='top',name='GS')
qf.add_bollinger_bands()
qf.iplot()
# Out:
# <div>                            <div id="db9cd7fa-ada7-4548-8680-88a1370cee54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # References:

# %% [markdown]
# - https://github.com/santosjorge/cufflinks
